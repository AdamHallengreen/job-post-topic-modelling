# %%
import polars as pl
import ast

# %%
from job_post_topic_modelling.utils.miscellaneous import try_inter

try_inter()
from exp_comparisons import print_all_experiments_text, load_experiment_csv,print_experiments,print_top_topics

# %%
test = load_experiment_csv("f9d8ec8")
# Out:
# ...
# EXPERIMENT: taboo-byes  (f9d8ec8f71cf)
# --------------------------------------------------------------------------------
# Topic 1 (411329 docs): 0_evner_politisk_kompetencer_tror forskellighed
#   Top words: evner, politisk, kompetencer, tror forskellighed, stillingen tror, forskellighed styrker, dynamik nytænkning, forståelse, samarbejdsevner, opfordrer derfor interesserede
#
# Topic 2 (400746 docs): 1_projekter_organisationen_samarbejde_rekruttering
#   Top words: projekter, organisationen, samarbejde, rekruttering, ledelse, administrative, tæt samarbejde, projektledelse, medarbejdernes, koordinering
#
# Topic 3 (380262 docs): 2_ansøgninger behandles_ansøgninger behandles løbende_kommune opfordrer søge_opfordrer søge stillingen
#   Top words: ansøgninger behandles, ansøgninger behandles løbende, kommune opfordrer søge, opfordrer søge stillingen, etnisk baggrund handicap, kommune opfordrer, opfordrer søge, elektronisk rekrutteringssystem, søge stillingen uanset, ansøgningerne
#
# ...

# %%
print_top_topics(test,n_topics=None)
# Out:
# Topic 1 (411329 docs): 0_evner_politisk_kompetencer_tror forskellighed
#   Top words: evner, politisk, kompetencer, tror forskellighed, stillingen tror, forskellighed styrker, dynamik nytænkning, forståelse, samarbejdsevner, opfordrer derfor interesserede
#
# Topic 2 (400746 docs): 1_projekter_organisationen_samarbejde_rekruttering
#   Top words: projekter, organisationen, samarbejde, rekruttering, ledelse, administrative, tæt samarbejde, projektledelse, medarbejdernes, koordinering
#
# Topic 3 (380262 docs): 2_ansøgninger behandles_ansøgninger behandles løbende_kommune opfordrer søge_opfordrer søge stillingen
#   Top words: ansøgninger behandles, ansøgninger behandles løbende, kommune opfordrer søge, opfordrer søge stillingen, etnisk baggrund handicap, kommune opfordrer, opfordrer søge, elektronisk rekrutteringssystem, søge stillingen uanset, ansøgningerne
#
# Topic 4 (376292 docs): 3_send ansøgning_send_sender ansøgning_knappen send ansøgning
# ...

# %%
small_2mio = load_experiment_csv("incog")
# Out:
# ...
# EXPERIMENT: incog-ryas  (a1b7d5880184)
# --------------------------------------------------------------------------------
# Topic 1 (26321 docs): 0_stillingen velkommen kontakte_vide stillingen_vide stillingen velkommen_kontakte afdelingsleder
#   Top words: stillingen velkommen kontakte, vide stillingen, vide stillingen velkommen, kontakte afdelingsleder, oplysninger stillingen, stillingen kontakte, yderligere oplysninger stillingen, oplysninger stillingen fås, stillingen fås henvendelse, vide stillingen kontakte
#
# Topic 2 (24656 docs): 1_børnenes_tilgang børn_anerkendende tilgang børn_give børnene
#   Top words: børnenes, tilgang børn, anerkendende tilgang børn, give børnene, børn forældre kolleger, tilgang børn forældre, børn forældre kollegaer, børneliv, lyst arbejde børn, børnenes trivsel
#
# Topic 3 (21757 docs): 2_projektleder_projektledelse_projektledere_projektlederen
# ...

# %%
big_2mio = load_experiment_csv("c9a9108")
# Out:
# ...
# EXPERIMENT: light-mesh  (c9a91084f629)
# --------------------------------------------------------------------------------
# Topic 1 (27185 docs): 0_stillingen velkommen kontakte_tlf_fås henvendelse_spørgsmål stillingen velkommen
#   Top words: stillingen velkommen kontakte, tlf, fås henvendelse, spørgsmål stillingen velkommen, stillingen kontakte, kontakte afdelingsleder, oplysninger stillingen fås, stillingen fås henvendelse, henvendelse, velkommen kontakte afdelingsleder
#
# Topic 2 (20148 docs): 1_maskinmester_bygningskonstruktør_håndværksmæssig_maskinarbejder
#   Top words: maskinmester, bygningskonstruktør, håndværksmæssig, maskinarbejder, produktionsteknolog, el, bygningsingeniør, håndværksmæssig uddannelse, svejsning, tømrer
#
# Topic 3 (16990 docs): 2_børnehavebørn_vuggestuebørn_børnehavegrupper_børn fordelt
#   Top words: børnehavebørn, vuggestuebørn, børnehavegrupper, børn fordelt, vuggestuegrupper, daginstitution, børnehave, børn år, børnehaven, børnehus
#
# ...
